# %%
import pandas as pd

# %%
data = pd.read_csv("https://files.challengerocket.com/files/lions-den-ing-2024/train_sample.csv")

# %%
data.shape
# Out:
# (3095, 307)

# %%
out = pd.read_csv("https://files.challengerocket.com/files/lions-den-ing-2024/out_of_time.csv")
